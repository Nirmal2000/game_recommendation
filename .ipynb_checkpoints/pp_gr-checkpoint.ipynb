# %%
from dotenv import load_dotenv
load_dotenv()
import requests
from bs4 import BeautifulSoup
import concurrent.futures
import numpy as np
import json
import os

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langgraph.graph import END, MessageGraph
from langchain_community.tools import BraveSearch
from langgraph.prebuilt import ToolExecutor
from langchain_core.tools import tool

# %%
llm_cache = {}

# %%
pp_model = ChatOpenAI(temperature=0, 
                   base_url='https://api.perplexity.ai', 
                   api_key=os.environ['PERPLEXITY_API_KEY'],
                  model='llama-3-sonar-large-32k-online')

# %%
def generate_answer(model, messages):
    messages_list = tuple([(i['role'], i['content']) for i in messages])
    if (model.model_name, messages_list) in llm_cache:
        return llm_cache[(model.model_name, messages_list)]
    result = model.invoke(messages).content
    llm_cache[(model.model_name, messages_list)] = result
    return llm_cache[(model.model_name, messages_list)]

# %%
def answer_query(model, query):

    messages = [        
        {'role': 'system', 'content': '''You are the best Game recommendation engine in the world. \ 
Given any type of query related to recommending video games you are supposed to provide a list of games that satisfy the user's request and also explain briefly for each game why. Return the results in a numbered list.'''},
        {'role': 'user', 'content': query+' Return the results in a numbered list and explain briefly why each is a good fit in 50 words.'}
    ]
    return generate_answer(model, messages)


class chatbot:
    def __init__(self, system_message):
        self.messages = [
            {'role': 'system', 'content': system_message}
        ]
        
    def restart(self, ):
        self.messages = []
    
    def ask_question(self, query):
        response = answer_query(query, self.messages)
        self.messages += [
            {'role': 'user', 'content': query},
            {'role': 'assistant', 'content': response}
        ]
        return self.messages

# %%
print(answer_query(pp_model,"Recommend me games that really good combat mechanics and brilliant story telling"))
# Out:
# Here are some games with great combat mechanics and brilliant storytelling:
#
# 1. **Baldur's Gate 3**: This game manages to balance open-ended RPG elements with a tightly paced and skillfully curated tale, making it an excellent choice for those looking for a narrative-driven experience with engaging combat[1].
#
# 2. **Alan Wake 2**: With an exceptional storyline, this game is a great fit for those who enjoy realistic tales and are looking for a game that will immerse them in its world[1].
#
# 3. **Cyberpunk 2077**: This game offers great combat, a compelling story, and meaningful choices, making it an excellent choice for those who enjoy RPGs with a strong narrative focus[3].
#
# 4. **Deus Ex**: As a sci-fi classic, Deus Ex is well worth a look for its engaging storyline and combat mechanics that have influenced modern game writing[1].
#
# 5. **Mass Effect 2**: This game is known for its strong influence on modern game writing and offers a memorable narrative with engaging combat[1].
#
# 6. **The Witcher 3**: With a compelling story, great combat, and meaningful choices, The Witcher 3 is a great fit for those who enjoy RPGs with a strong narrative focus[3].
#
# 7. **Dragon Quest 11**: This game offers a classic turn-based system modernized for new players, making it an excellent choice for those who enjoy traditional RPG combat with a cinematic twist[5].
#
# 8. **Tales of Graces F**: With arguably the best and most accessible battle system in the Tales series, this game is a great fit for those who enjoy real-time combat with a focus on speed and timing[5].
#
# 9. **Bloodborne**: Created by the developers of Dark Souls, Bloodborne offers challenging and reactive combat in a Lovecraftian Soulslike setting, making it an excellent choice for those who enjoy fast-paced action RPGs[5].
#
# 10. **Kingdom Come Deliverance**: This game offers a realistic and historically inspired setting with great combat and a compelling story, making it an excellent choice for those who enjoy RPGs with a strong focus on realism[3].

# %%
class RAWG:
    def __init__(self, api_key):
        self.ak = api_key
        self.games_url = 'https://api.rawg.io/api/games'
    def search_game(self, query):
        params = {
            'key': self.ak,
            'page': 1,           # Specify which page of results to return
            'page_size': 10,     # Specify the number of results per page
            'search': query,
            
        }
        return requests.get(self.games_url, params)

# %%
rawg = RAWG(os.environ['RAWG_API_KEY'])

# %%
response = rawg.search_game("Baldur's Gate 3")

# %%
game = json.loads(response.content)

# %%
game['results']
# Out:
# [{'slug': 'baldurs-gate-3',
#   'name': "Baldur's Gate III",
#   'playtime': 12,
#   'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 187, 'name': 'PlayStation 5', 'slug': 'playstation5'}},
#    {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}}],
#   'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}},
#    {'store': {'id': 3,
#      'name': 'PlayStation Store',
#      'slug': 'playstation-store'}},
#    {'store': {'id': 5, 'name': 'GOG', 'slug': 'gog'}}],
#   'released': '2023-08-03',
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/games/699/69907ecf13f172e9e144069769c3be73.jpg',
#   'rating': 4.56,
#   'rating_top': 5,
#   'ratings': [{'id': 5,
#     'title': 'exceptional',
#     'count': 428,
#     'percent': 74.83},
#    {'id': 4, 'title': 'recommended', 'count': 89, 'percent': 15.56},
#    {'id': 3, 'title': 'meh', 'count': 28, 'percent': 4.9},
#    {'id': 1, 'title': 'skip', 'count': 27, 'percent': 4.72}],
#   'ratings_count': 553,
#   'reviews_text_count': 13,
#   'added': 3245,
#   'added_by_status': {'yet': 294,
#    'owned': 1467,
#    'beaten': 310,
#    'toplay': 772,
#    'dropped': 124,
#    'playing': 278},
#   'metacritic': 97,
#   'suggestions_count': 570,
#   'updated': '2024-05-02T13:10:44',
#   'id': 324997,
#   'score': '79.9135',
#   'clip': None,
#   'tags': [{'id': 31,
#     'name': 'Singleplayer',
#     'slug': 'singleplayer',
#     'language': 'eng',
#     'games_count': 220522,
#     'image_background': 'https://media.rawg.io/media/games/511/5118aff5091cb3efec399c808f8c598f.jpg'},
#    {'id': 42396,
#     'name': 'Для одного игрока',
#     'slug': 'dlia-odnogo-igroka',
#     'language': 'rus',
#     'games_count': 46028,
#     'image_background': 'https://media.rawg.io/media/games/8cc/8cce7c0e99dcc43d66c8efd42f9d03e3.jpg'},
#    {'id': 42392,
#     'name': 'Приключение',
#     'slug': 'prikliuchenie',
#     'language': 'rus',
#     'games_count': 36505,
#     'image_background': 'https://media.rawg.io/media/games/2ba/2bac0e87cf45e5b508f227d281c9252a.jpg'},
#    {'id': 40847,
#     'name': 'Steam Achievements',
#     'slug': 'steam-achievements',
#     'language': 'eng',
#     'games_count': 36657,
#     'image_background': 'https://media.rawg.io/media/games/490/49016e06ae2103881ff6373248843069.jpg'},
#    {'id': 7,
#     'name': 'Multiplayer',
#     'slug': 'multiplayer',
#     'language': 'eng',
#     'games_count': 37503,
#     'image_background': 'https://media.rawg.io/media/games/b49/b4912b5dbfc7ed8927b65f05b8507f6c.jpg'},
#    {'id': 40849,
#     'name': 'Steam Cloud',
#     'slug': 'steam-cloud',
#     'language': 'eng',
#     'games_count': 17278,
#     'image_background': 'https://media.rawg.io/media/games/b49/b4912b5dbfc7ed8927b65f05b8507f6c.jpg'},
#    {'id': 42425,
#     'name': 'Для нескольких игроков',
#     'slug': 'dlia-neskolkikh-igrokov',
#     'language': 'rus',
#     'games_count': 9491,
#     'image_background': 'https://media.rawg.io/media/games/4a0/4a0a1316102366260e6f38fd2a9cfdce.jpg'},
#    {'id': 42394,
#     'name': 'Глубокий сюжет',
#     'slug': 'glubokii-siuzhet',
#     'language': 'rus',
#     'games_count': 11861,
#     'image_background': 'https://media.rawg.io/media/games/4be/4be6a6ad0364751a96229c56bf69be59.jpg'},
#    {'id': 24,
#     'name': 'RPG',
#     'slug': 'rpg',
#     'language': 'eng',
#     'games_count': 20341,
#     'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'},
#    {'id': 18,
#     'name': 'Co-op',
#     'slug': 'co-op',
#     'language': 'eng',
#     'games_count': 11289,
#     'image_background': 'https://media.rawg.io/media/games/d0f/d0f91fe1d92332147e5db74e207cfc7a.jpg'},
#    {'id': 42412,
#     'name': 'Ролевая игра',
#     'slug': 'rolevaia-igra',
#     'language': 'rus',
#     'games_count': 16754,
#     'image_background': 'https://media.rawg.io/media/games/4e0/4e0e7b6d6906a131307c94266e5c9a1c.jpg'},
#    {'id': 42421,
#     'name': 'Стратегия',
#     'slug': 'strategiia',
#     'language': 'rus',
#     'games_count': 18185,
#     'image_background': 'https://media.rawg.io/media/games/858/858c016de0cf7bc21a57dcc698a04a0c.jpg'},
#    {'id': 42435,
#     'name': 'Шедевр',
#     'slug': 'shedevr',
#     'language': 'rus',
#     'games_count': 1059,
#     'image_background': 'https://media.rawg.io/media/games/b49/b4912b5dbfc7ed8927b65f05b8507f6c.jpg'},
#    {'id': 42413,
#     'name': 'Симулятор',
#     'slug': 'simuliator',
#     'language': 'rus',
#     'games_count': 18354,
#     'image_background': 'https://media.rawg.io/media/games/08b/08b2eee52a9876a48b955e5149affe5b.jpg'},
#    {'id': 9,
#     'name': 'Online Co-Op',
#     'slug': 'online-co-op',
#     'language': 'eng',
#     'games_count': 5356,
#     'image_background': 'https://media.rawg.io/media/games/15c/15c95a4915f88a3e89c821526afe05fc.jpg'},
#    {'id': 42480,
#     'name': 'Фэнтези',
#     'slug': 'fentezi',
#     'language': 'rus',
#     'games_count': 10958,
#     'image_background': 'https://media.rawg.io/media/games/d0f/d0f91fe1d92332147e5db74e207cfc7a.jpg'},
#    {'id': 64,
#     'name': 'Fantasy',
#     'slug': 'fantasy',
#     'language': 'eng',
#     'games_count': 27201,
#     'image_background': 'https://media.rawg.io/media/games/d2c/d2c74dacd89fd817c2deb625b01adb1a.jpg'},
#    {'id': 42444,
#     'name': 'Песочница',
#     'slug': 'pesochnitsa',
#     'language': 'rus',
#     'games_count': 3977,
#     'image_background': 'https://media.rawg.io/media/games/25c/25c4776ab5723d5d735d8bf617ca12d9.jpg'},
#    {'id': 198,
#     'name': 'Split Screen',
#     'slug': 'split-screen',
#     'language': 'eng',
#     'games_count': 6504,
#     'image_background': 'https://media.rawg.io/media/games/3be/3be0e624424d3453005019799a760af2.jpg'},
#    {'id': 397,
#     'name': 'Online multiplayer',
#     'slug': 'online-multiplayer',
#     'language': 'eng',
#     'games_count': 3805,
#     'image_background': 'https://media.rawg.io/media/games/fba/fbae1bcfae1feffda6a11fbc1c939420.jpg'},
#    {'id': 75,
#     'name': 'Local Co-Op',
#     'slug': 'local-co-op',
#     'language': 'eng',
#     'games_count': 5346,
#     'image_background': 'https://media.rawg.io/media/games/1e5/1e5e33b88be978f451196a751424a72e.jpg'},
#    {'id': 72,
#     'name': 'Local Multiplayer',
#     'slug': 'local-multiplayer',
#     'language': 'eng',
#     'games_count': 13047,
#     'image_background': 'https://media.rawg.io/media/games/8cc/8cce7c0e99dcc43d66c8efd42f9d03e3.jpg'},
#    {'id': 40832,
#     'name': 'Cross-Platform Multiplayer',
#     'slug': 'cross-platform-multiplayer',
#     'language': 'eng',
#     'games_count': 2552,
#     'image_background': 'https://media.rawg.io/media/games/9f1/9f1891779cb20f44de93cef33b067e50.jpg'},
#    {'id': 468,
#     'name': 'role-playing',
#     'slug': 'role-playing',
#     'language': 'eng',
#     'games_count': 1567,
#     'image_background': 'https://media.rawg.io/media/games/f99/f9979698c43fd84c3ab69280576dd3af.jpg'},
#    {'id': 42424,
#     'name': 'Пошаговая',
#     'slug': 'poshagovaia',
#     'language': 'rus',
#     'games_count': 1698,
#     'image_background': 'https://media.rawg.io/media/games/0d4/0d4e5446db732e2fcce34d1dcb4dd914.jpg'},
#    {'id': 121,
#     'name': 'Character Customization',
#     'slug': 'character-customization',
#     'language': 'eng',
#     'games_count': 4450,
#     'image_background': 'https://media.rawg.io/media/games/6fc/6fcf4cd3b17c288821388e6085bb0fc9.jpg'},
#    {'id': 40833,
#     'name': 'Captions available',
#     'slug': 'captions-available',
#     'language': 'eng',
#     'games_count': 1322,
#     'image_background': 'https://media.rawg.io/media/games/46d/46d98e6910fbc0706e2948a7cc9b10c5.jpg'},
#    {'id': 42419,
#     'name': 'Рогалик',
#     'slug': 'rogalik',
#     'language': 'rus',
#     'games_count': 3937,
#     'image_background': 'https://media.rawg.io/media/screenshots/71c/71c015df012029897e87ac00b7a8de4c.jpg'},
#    {'id': 99,
#     'name': 'Isometric',
#     'slug': 'isometric',
#     'language': 'eng',
#     'games_count': 4364,
#     'image_background': 'https://media.rawg.io/media/games/a92/a92272ea5cfc35b8ad6317fbd81ce0f6.jpg'},
#    {'id': 82,
#     'name': 'Magic',
#     'slug': 'magic',
#     'language': 'eng',
#     'games_count': 9210,
#     'image_background': 'https://media.rawg.io/media/games/ccf/ccf26f6e3d553a04f0033a8107a521b8.jpg'},
#    {'id': 42551,
#     'name': 'Менеджмент',
#     'slug': 'menedzhment',
#     'language': 'rus',
#     'games_count': 3312,
#     'image_background': 'https://media.rawg.io/media/games/000/0002b2686a50b30762fb6040a8d9187f.jpg'},
#    {'id': 40937,
#     'name': 'Steam Trading Cards',
#     'slug': 'steam-trading-cards-2',
#     'language': 'eng',
#     'games_count': 614,
#     'image_background': 'https://media.rawg.io/media/games/1fa/1fa75f0895240b12fc65cc98ae9649fd.jpg'},
#    {'id': 42552,
#     'name': 'Можно приостановить',
#     'slug': 'mozhno-priostanovit',
#     'language': 'rus',
#     'games_count': 284,
#     'image_background': 'https://media.rawg.io/media/games/dc0/dc0926d3f84ffbcc00968fe8a6f0aed3.jpg'},
#    {'id': 42521,
#     'name': 'Экономика',
#     'slug': 'ekonomika',
#     'language': 'rus',
#     'games_count': 1401,
#     'image_background': 'https://media.rawg.io/media/screenshots/125/1258337895195f87eb5465eb9d5d5596.jpg'},
#    {'id': 238,
#     'name': 'CRPG',
#     'slug': 'crpg',
#     'language': 'eng',
#     'games_count': 999,
#     'image_background': 'https://media.rawg.io/media/games/699/69907ecf13f172e9e144069769c3be73.jpg'},
#    {'id': 206,
#     'name': 'Party-Based RPG',
#     'slug': 'party-based-rpg',
#     'language': 'eng',
#     'games_count': 1005,
#     'image_background': 'https://media.rawg.io/media/games/add/add07a75a3f1e479b55dbe920d9fb13d.jpg'},
#    {'id': 467,
#     'name': 'Role Playing Game',
#     'slug': 'role-playing-game',
#     'language': 'eng',
#     'games_count': 19,
#     'image_background': 'https://media.rawg.io/media/games/8ea/8ea1e2850d7568bc9733d546c0ac6ce1.jpg'},
#    {'id': 574,
#     'name': 'Dungeons & Dragons',
#     'slug': 'dungeons-dragons',
#     'language': 'eng',
#     'games_count': 185,
#     'image_background': 'https://media.rawg.io/media/games/246/246367eab7ccfaaad14ad4507deee067.jpeg'}],
#   'esrb_rating': {'id': 4,
#    'name': 'Mature',
#    'slug': 'mature',
#    'name_en': 'Mature',
#    'name_ru': 'С 17 лет'},
#   'user_game': None,
#   'reviews_count': 572,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/games/699/69907ecf13f172e9e144069769c3be73.jpg'},
#    {'id': 2300708,
#     'image': 'https://media.rawg.io/media/screenshots/a67/a676cdec0eadc42a133ac49e7f2e1aac.jpg'},
#    {'id': 2300709,
#     'image': 'https://media.rawg.io/media/screenshots/705/705846f6583a6da009a0ae7fcdece36d.jpg'},
#    {'id': 2300710,
#     'image': 'https://media.rawg.io/media/screenshots/d29/d29b1d2726d69432d2b4180a79b9ee9d.jpg'},
#    {'id': 2300711,
#     'image': 'https://media.rawg.io/media/screenshots/ed1/ed19ec8ce43f9dd3553df4a6d9301f61.jpg'},
#    {'id': 2300712,
#     'image': 'https://media.rawg.io/media/screenshots/6c8/6c8983d658a4a24dc8eb9d2f88f1dabf.jpg'},
#    {'id': 2300713,
#     'image': 'https://media.rawg.io/media/screenshots/92c/92cbe16a795afbc9d9837ed9eae4f22b.jpg'}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#    {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}}],
#   'genres': [{'id': 10, 'name': 'Strategy', 'slug': 'strategy'},
#    {'id': 3, 'name': 'Adventure', 'slug': 'adventure'},
#    {'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#  {'slug': 'baldurs-gate',
#   'name': "Baldur's Gate",
#   'playtime': 76,
#   'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 3, 'name': 'iOS', 'slug': 'ios'}},
#    {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}}],
#   'stores': [{'store': {'id': 4,
#      'name': 'App Store',
#      'slug': 'apple-appstore'}}],
#   'released': '1998-12-21',
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/games/a91/a9108384b5d691080b294cd744f350c9.jpg',
#   'rating': 4.36,
#   'rating_top': 5,
#   'ratings': [{'id': 5, 'title': 'exceptional', 'count': 91, 'percent': 54.17},
#    {'id': 4, 'title': 'recommended', 'count': 61, 'percent': 36.31},
#    {'id': 3, 'title': 'meh', 'count': 9, 'percent': 5.36},
#    {'id': 1, 'title': 'skip', 'count': 7, 'percent': 4.17}],
#   'ratings_count': 167,
#   'reviews_text_count': 0,
#   'added': 382,
#   'added_by_status': {'yet': 46,
#    'owned': 78,
#    'beaten': 148,
#    'toplay': 57,
#    'dropped': 46,
#    'playing': 7},
#   'metacritic': 91,
#   'suggestions_count': 523,
#   'updated': '2024-03-28T10:50:59',
#   'id': 31495,
#   'score': '34.462524',
#   'clip': None,
#   'tags': [{'id': 7,
#     'name': 'Multiplayer',
#     'slug': 'multiplayer',
#     'language': 'eng',
#     'games_count': 37503,
#     'image_background': 'https://media.rawg.io/media/games/b49/b4912b5dbfc7ed8927b65f05b8507f6c.jpg'},
#    {'id': 70,
#     'name': 'War',
#     'slug': 'war',
#     'language': 'eng',
#     'games_count': 9188,
#     'image_background': 'https://media.rawg.io/media/games/03d/03d17d237f9541b67a13f9425ced4ca4.jpg'},
#    {'id': 808,
#     'name': 'character',
#     'slug': 'character',
#     'language': 'eng',
#     'games_count': 8824,
#     'image_background': 'https://media.rawg.io/media/games/a8d/a8d08a70ce7a4f3263bedf5d764fc538.jpg'},
#    {'id': 215,
#     'name': 'Dragons',
#     'slug': 'dragons',
#     'language': 'eng',
#     'games_count': 2565,
#     'image_background': 'https://media.rawg.io/media/games/62c/62c7c8b28a27b83680b22fb9d33fc619.jpg'},
#    {'id': 625,
#     'name': 'party',
#     'slug': 'party',
#     'language': 'eng',
#     'games_count': 4085,
#     'image_background': 'https://media.rawg.io/media/screenshots/7c6/7c6d6a357059121a3c672a795e432374.jpg'},
#    {'id': 2326,
#     'name': 'explore',
#     'slug': 'explore',
#     'language': 'eng',
#     'games_count': 3308,
#     'image_background': 'https://media.rawg.io/media/screenshots/b62/b6264b884fd583f52612de6a0cbd0de8.jpg'},
#    {'id': 1709,
#     'name': 'work',
#     'slug': 'work',
#     'language': 'eng',
#     'games_count': 9211,
#     'image_background': 'https://media.rawg.io/media/games/b5c/b5c7d7fa2eb9f136cedb51701384564a.jpg'},
#    {'id': 878,
#     'name': 'sword',
#     'slug': 'sword',
#     'language': 'eng',
#     'games_count': 1422,
#     'image_background': 'https://media.rawg.io/media/games/bcd/bcdadb5dd2be66dd4dd1f657275b3f8e.jpg'}],
#   'esrb_rating': {'id': 3,
#    'name': 'Teen',
#    'slug': 'teen',
#    'name_en': 'Teen',
#    'name_ru': 'С 13 лет'},
#   'user_game': None,
#   'reviews_count': 168,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/games/a91/a9108384b5d691080b294cd744f350c9.jpg'},
#    {'id': 317503,
#     'image': 'https://media.rawg.io/media/screenshots/c39/c399e200d32647a6028c776d50c5ffae.jpg'},
#    {'id': 317504,
#     'image': 'https://media.rawg.io/media/screenshots/c81/c81d2be2d79f438e48176ebe227162de.jpg'},
#    {'id': 317505,
#     'image': 'https://media.rawg.io/media/screenshots/0d7/0d7a370f4d8ae0c59d1945d3a151e456.jpg'},
#    {'id': 317506,
#     'image': 'https://media.rawg.io/media/screenshots/117/1179ac52027bedb172cbfa9e53d6e8c4.jpg'},
#    {'id': 317507,
#     'image': 'https://media.rawg.io/media/screenshots/74b/74bbc3c55708d740c69a6dc8fe96a176.jpg'},
#    {'id': 317508,
#     'image': 'https://media.rawg.io/media/screenshots/298/2980ff54971c12009924f94cc4313cbb.jpg'}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 4, 'name': 'iOS', 'slug': 'ios'}},
#    {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}}],
#   'genres': [{'id': 10, 'name': 'Strategy', 'slug': 'strategy'},
#    {'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#  {'slug': 'baldurs-gate-dark-alliance',
#   'name': "Baldur's Gate: Dark Alliance",
#   'playtime': 1,
#   'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 187, 'name': 'PlayStation 5', 'slug': 'playstation5'}},
#    {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4'}},
#    {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one'}},
#    {'platform': {'id': 186,
#      'name': 'Xbox Series S/X',
#      'slug': 'xbox-series-x'}},
#    {'platform': {'id': 7,
#      'name': 'Nintendo Switch',
#      'slug': 'nintendo-switch'}},
#    {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}},
#    {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}},
#    {'platform': {'id': 80, 'name': 'Xbox', 'slug': 'xbox-old'}},
#    {'platform': {'id': 15, 'name': 'PlayStation 2', 'slug': 'playstation2'}},
#    {'platform': {'id': 105, 'name': 'GameCube', 'slug': 'gamecube'}},
#    {'platform': {'id': 24,
#      'name': 'Game Boy Advance',
#      'slug': 'game-boy-advance'}}],
#   'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}},
#    {'store': {'id': 3,
#      'name': 'PlayStation Store',
#      'slug': 'playstation-store'}},
#    {'store': {'id': 2, 'name': 'Xbox Store', 'slug': 'xbox-store'}},
#    {'store': {'id': 5, 'name': 'GOG', 'slug': 'gog'}},
#    {'store': {'id': 6, 'name': 'Nintendo Store', 'slug': 'nintendo'}},
#    {'store': {'id': 11, 'name': 'Epic Games', 'slug': 'epic-games'}}],
#   'released': '2001-12-02',
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/games/a0d/a0d24e2e37d0710a63df12df089e71f6.jpg',
#   'rating': 3.92,
#   'rating_top': 4,
#   'ratings': [{'id': 4, 'title': 'recommended', 'count': 31, 'percent': 63.27},
#    {'id': 5, 'title': 'exceptional', 'count': 10, 'percent': 20.41},
#    {'id': 3, 'title': 'meh', 'count': 5, 'percent': 10.2},
#    {'id': 1, 'title': 'skip', 'count': 3, 'percent': 6.12}],
#   'ratings_count': 49,
#   'reviews_text_count': 0,
#   'added': 192,
#   'added_by_status': {'yet': 16,
#    'owned': 83,
#    'beaten': 36,
#    'toplay': 32,
#    'dropped': 20,
#    'playing': 5},
#   'metacritic': 72,
#   'suggestions_count': 923,
#   'updated': '2023-12-17T21:49:53',
#   'id': 53146,
#   'score': '31.352867',
#   'clip': None,
#   'tags': [{'id': 31,
#     'name': 'Singleplayer',
#     'slug': 'singleplayer',
#     'language': 'eng',
#     'games_count': 220522,
#     'image_background': 'https://media.rawg.io/media/games/511/5118aff5091cb3efec399c808f8c598f.jpg'},
#    {'id': 42396,
#     'name': 'Для одного игрока',
#     'slug': 'dlia-odnogo-igroka',
#     'language': 'rus',
#     'games_count': 46028,
#     'image_background': 'https://media.rawg.io/media/games/8cc/8cce7c0e99dcc43d66c8efd42f9d03e3.jpg'},
#    {'id': 42417,
#     'name': 'Экшен',
#     'slug': 'ekshen',
#     'language': 'rus',
#     'games_count': 38542,
#     'image_background': 'https://media.rawg.io/media/games/2ba/2bac0e87cf45e5b508f227d281c9252a.jpg'},
#    {'id': 7,
#     'name': 'Multiplayer',
#     'slug': 'multiplayer',
#     'language': 'eng',
#     'games_count': 37503,
#     'image_background': 'https://media.rawg.io/media/games/b49/b4912b5dbfc7ed8927b65f05b8507f6c.jpg'},
#    {'id': 40836,
#     'name': 'Full controller support',
#     'slug': 'full-controller-support',
#     'language': 'eng',
#     'games_count': 17269,
#     'image_background': 'https://media.rawg.io/media/games/8a0/8a02f84a5916ede2f923b88d5f8217ba.jpg'},
#    {'id': 40849,
#     'name': 'Steam Cloud',
#     'slug': 'steam-cloud',
#     'language': 'eng',
#     'games_count': 17278,
#     'image_background': 'https://media.rawg.io/media/games/b49/b4912b5dbfc7ed8927b65f05b8507f6c.jpg'},
#    {'id': 42394,
#     'name': 'Глубокий сюжет',
#     'slug': 'glubokii-siuzhet',
#     'language': 'rus',
#     'games_count': 11861,
#     'image_background': 'https://media.rawg.io/media/games/4be/4be6a6ad0364751a96229c56bf69be59.jpg'},
#    {'id': 24,
#     'name': 'RPG',
#     'slug': 'rpg',
#     'language': 'eng',
#     'games_count': 20341,
#     'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'},
#    {'id': 18,
#     'name': 'Co-op',
#     'slug': 'co-op',
#     'language': 'eng',
#     'games_count': 11289,
#     'image_background': 'https://media.rawg.io/media/games/d0f/d0f91fe1d92332147e5db74e207cfc7a.jpg'},
#    {'id': 42412,
#     'name': 'Ролевая игра',
#     'slug': 'rolevaia-igra',
#     'language': 'rus',
#     'games_count': 16754,
#     'image_background': 'https://media.rawg.io/media/games/4e0/4e0e7b6d6906a131307c94266e5c9a1c.jpg'},
#    {'id': 118,
#     'name': 'Story Rich',
#     'slug': 'story-rich',
#     'language': 'eng',
#     'games_count': 21003,
#     'image_background': 'https://media.rawg.io/media/games/8a0/8a02f84a5916ede2f923b88d5f8217ba.jpg'},
#    {'id': 411,
#     'name': 'cooperative',
#     'slug': 'cooperative',
#     'language': 'eng',
#     'games_count': 4818,
#     'image_background': 'https://media.rawg.io/media/games/dd5/dd50d4266915d56dd5b63ae1bf72606a.jpg'},
#    {'id': 42480,
#     'name': 'Фэнтези',
#     'slug': 'fentezi',
#     'language': 'rus',
#     'games_count': 10958,
#     'image_background': 'https://media.rawg.io/media/games/d0f/d0f91fe1d92332147e5db74e207cfc7a.jpg'},
#    {'id': 64,
#     'name': 'Fantasy',
#     'slug': 'fantasy',
#     'language': 'eng',
#     'games_count': 27201,
#     'image_background': 'https://media.rawg.io/media/games/d2c/d2c74dacd89fd817c2deb625b01adb1a.jpg'},
#    {'id': 198,
#     'name': 'Split Screen',
#     'slug': 'split-screen',
#     'language': 'eng',
#     'games_count': 6504,
#     'image_background': 'https://media.rawg.io/media/games/3be/3be0e624424d3453005019799a760af2.jpg'},
#    {'id': 75,
#     'name': 'Local Co-Op',
#     'slug': 'local-co-op',
#     'language': 'eng',
#     'games_count': 5346,
#     'image_background': 'https://media.rawg.io/media/games/1e5/1e5e33b88be978f451196a751424a72e.jpg'},
#    {'id': 97,
#     'name': 'Action RPG',
#     'slug': 'action-rpg',
#     'language': 'eng',
#     'games_count': 6656,
#     'image_background': 'https://media.rawg.io/media/games/8d4/8d46786ca86b1d95f3dc7e700e2dc4dd.jpg'},
#    {'id': 42489,
#     'name': 'Ролевой экшен',
#     'slug': 'rolevoi-ekshen',
#     'language': 'rus',
#     'games_count': 3643,
#     'image_background': 'https://media.rawg.io/media/games/157/15742f2f67eacff546738e1ab5c19d20.jpg'},
#    {'id': 41,
#     'name': 'Dark',
#     'slug': 'dark',
#     'language': 'eng',
#     'games_count': 15406,
#     'image_background': 'https://media.rawg.io/media/games/4fb/4fb548e4816c84d1d70f1a228fb167cc.jpg'},
#    {'id': 468,
#     'name': 'role-playing',
#     'slug': 'role-playing',
#     'language': 'eng',
#     'games_count': 1567,
#     'image_background': 'https://media.rawg.io/media/games/f99/f9979698c43fd84c3ab69280576dd3af.jpg'},
#    {'id': 42487,
#     'name': 'Слэшер',
#     'slug': 'slesher',
#     'language': 'rus',
#     'games_count': 2578,
#     'image_background': 'https://media.rawg.io/media/games/9fb/9fbf956a16249def7625ab5dc3d09515.jpg'},
#    {'id': 68,
#     'name': 'Hack and Slash',
#     'slug': 'hack-and-slash',
#     'language': 'eng',
#     'games_count': 4069,
#     'image_background': 'https://media.rawg.io/media/games/4e0/4e0e7b6d6906a131307c94266e5c9a1c.jpg'},
#    {'id': 42530,
#     'name': 'Кастомизация персонажа',
#     'slug': 'kastomizatsiia-personazha',
#     'language': 'rus',
#     'games_count': 3674,
#     'image_background': 'https://media.rawg.io/media/games/c22/c22d804ac753c72f2617b3708a625dec.jpg'},
#    {'id': 121,
#     'name': 'Character Customization',
#     'slug': 'character-customization',
#     'language': 'eng',
#     'games_count': 4450,
#     'image_background': 'https://media.rawg.io/media/games/6fc/6fcf4cd3b17c288821388e6085bb0fc9.jpg'},
#    {'id': 40833,
#     'name': 'Captions available',
#     'slug': 'captions-available',
#     'language': 'eng',
#     'games_count': 1322,
#     'image_background': 'https://media.rawg.io/media/games/46d/46d98e6910fbc0706e2948a7cc9b10c5.jpg'},
#    {'id': 42576,
#     'name': 'Изометрия',
#     'slug': 'izometriia',
#     'language': 'rus',
#     'games_count': 1899,
#     'image_background': 'https://media.rawg.io/media/games/d4b/d4bcd78873edd9992d93aff9cc8db0c8.jpg'},
#    {'id': 99,
#     'name': 'Isometric',
#     'slug': 'isometric',
#     'language': 'eng',
#     'games_count': 4364,
#     'image_background': 'https://media.rawg.io/media/games/a92/a92272ea5cfc35b8ad6317fbd81ce0f6.jpg'},
#    {'id': 571,
#     'name': '3D',
#     'slug': '3d',
#     'language': 'eng',
#     'games_count': 82215,
#     'image_background': 'https://media.rawg.io/media/games/d97/d97f663b752a6484df105993f17abb49.jpg'},
#    {'id': 1465,
#     'name': 'combat',
#     'slug': 'combat',
#     'language': 'eng',
#     'games_count': 11665,
#     'image_background': 'https://media.rawg.io/media/games/73d/73db43df633477d4604c7248292f34b2.jpg'},
#    {'id': 82,
#     'name': 'Magic',
#     'slug': 'magic',
#     'language': 'eng',
#     'games_count': 9210,
#     'image_background': 'https://media.rawg.io/media/games/ccf/ccf26f6e3d553a04f0033a8107a521b8.jpg'},
#    {'id': 42478,
#     'name': 'Магия',
#     'slug': 'magiia',
#     'language': 'rus',
#     'games_count': 3847,
#     'image_background': 'https://media.rawg.io/media/games/f6b/f6bed028b02369d4cab548f4f9337e81.jpg'},
#    {'id': 42512,
#     'name': 'Олдскул',
#     'slug': 'oldskul',
#     'language': 'rus',
#     'games_count': 3600,
#     'image_background': 'https://media.rawg.io/media/games/c80/c80bcf321da44d69b18a06c04d942662.jpg'},
#    {'id': 48,
#     'name': 'Dungeon Crawler',
#     'slug': 'dungeon-crawler',
#     'language': 'eng',
#     'games_count': 6698,
#     'image_background': 'https://media.rawg.io/media/games/cef/cefedf18016cbab466861eb698daf988.jpg'},
#    {'id': 981,
#     'name': 'battle',
#     'slug': 'battle',
#     'language': 'eng',
#     'games_count': 10618,
#     'image_background': 'https://media.rawg.io/media/screenshots/db5/db5ab0d41a2a57274902d32ea8e6f1ec.jpg'},
#    {'id': 1867,
#     'name': 'puzzles',
#     'slug': 'puzzles',
#     'language': 'eng',
#     'games_count': 8791,
#     'image_background': 'https://media.rawg.io/media/games/de6/de66bc4c72b45c3bb906c85d0628112d.jpg'},
#    {'id': 171,
#     'name': 'PvE',
#     'slug': 'pve',
#     'language': 'eng',
#     'games_count': 4589,
#     'image_background': 'https://media.rawg.io/media/screenshots/8a7/8a7586c647e10e6b6959df16d8bdc909.jpg'},
#    {'id': 42567,
#     'name': 'Игра против ИИ',
#     'slug': 'igra-protiv-ii',
#     'language': 'rus',
#     'games_count': 2327,
#     'image_background': 'https://media.rawg.io/media/games/f87/f87457e8347484033cb34cde6101d08d.jpg'},
#    {'id': 808,
#     'name': 'character',
#     'slug': 'character',
#     'language': 'eng',
#     'games_count': 8824,
#     'image_background': 'https://media.rawg.io/media/games/a8d/a8d08a70ce7a4f3263bedf5d764fc538.jpg'},
#    {'id': 58127,
#     'name': 'Бой',
#     'slug': 'boi-2',
#     'language': 'rus',
#     'games_count': 6548,
#     'image_background': 'https://media.rawg.io/media/games/e85/e851f527ab0658519436342ee73da191.jpg'},
#    {'id': 42626,
#     'name': 'Компьютерная ролевая игра',
#     'slug': 'kompiuternaia-rolevaia-igra',
#     'language': 'rus',
#     'games_count': 1005,
#     'image_background': 'https://media.rawg.io/media/games/963/9639183ff27251b0b686acaa6aac0297.jpg'},
#    {'id': 215,
#     'name': 'Dragons',
#     'slug': 'dragons',
#     'language': 'eng',
#     'games_count': 2565,
#     'image_background': 'https://media.rawg.io/media/games/62c/62c7c8b28a27b83680b22fb9d33fc619.jpg'},
#    {'id': 238,
#     'name': 'CRPG',
#     'slug': 'crpg',
#     'language': 'eng',
#     'games_count': 999,
#     'image_background': 'https://media.rawg.io/media/games/699/69907ecf13f172e9e144069769c3be73.jpg'},
#    {'id': 581,
#     'name': 'Epic',
#     'slug': 'epic',
#     'language': 'eng',
#     'games_count': 4093,
#     'image_background': 'https://media.rawg.io/media/games/b42/b42b05096de6668833bbab38f6099c6a.jpg'},
#    {'id': 295,
#     'name': 'Soundtrack',
#     'slug': 'soundtrack',
#     'language': 'eng',
#     'games_count': 2984,
#     'image_background': 'https://media.rawg.io/media/games/ed0/ed05e3f2303b644e3b95b409a7909f5a.jpg'},
#    {'id': 45201,
#     'name': 'Remote Play Together',
#     'slug': 'remote-play-together',
#     'language': 'eng',
#     'games_count': 2685,
#     'image_background': 'https://media.rawg.io/media/screenshots/cc0/cc064ab715ba4195ac6d26250218e307.jpg'},
#    {'id': 46112,
#     'name': 'Shared/Split Screen Co-op',
#     'slug': 'sharedsplit-screen-co-op',
#     'language': 'eng',
#     'games_count': 1734,
#     'image_background': 'https://media.rawg.io/media/games/3f4/3f43f03406a5ea087352bf32d60e3a0a.jpg'},
#    {'id': 2326,
#     'name': 'explore',
#     'slug': 'explore',
#     'language': 'eng',
#     'games_count': 3308,
#     'image_background': 'https://media.rawg.io/media/screenshots/b62/b6264b884fd583f52612de6a0cbd0de8.jpg'},
#    {'id': 2590,
#     'name': 'fun',
#     'slug': 'fun',
#     'language': 'eng',
#     'games_count': 29169,
#     'image_background': 'https://media.rawg.io/media/games/075/0753492cda7ee3c9bd4a3ca673fd0c8c.jpg'},
#    {'id': 570,
#     'name': 'Old School',
#     'slug': 'old-school',
#     'language': 'eng',
#     'games_count': 3351,
#     'image_background': 'https://media.rawg.io/media/screenshots/1d6/1d66c38dedaf68ff0bd73087128016a3.jpg'},
#    {'id': 58131,
#     'name': 'Подземелья',
#     'slug': 'podzemelia',
#     'language': 'rus',
#     'games_count': 1750,
#     'image_background': 'https://media.rawg.io/media/screenshots/029/029473dcb7952e3eb154fbae4078437f.jpg'},
#    {'id': 70354,
#     'name': 'Локальный кооператив',
#     'slug': 'lokalnyi-kooperativ',
#     'language': 'rus',
#     'games_count': 866,
#     'image_background': 'https://media.rawg.io/media/screenshots/166/166e17d403f74bd4494ae4dcb289ad2c.jpg'},
#    {'id': 409,
#     'name': 'co-op multiplayer',
#     'slug': 'co-op-multiplayer',
#     'language': 'eng',
#     'games_count': 8,
#     'image_background': 'https://media.rawg.io/media/games/d22/d22ea1bfb636fbf1a9c235cc304312a8.jpg'},
#    {'id': 1787,
#     'name': 'mobile',
#     'slug': 'mobile',
#     'language': 'eng',
#     'games_count': 4587,
#     'image_background': 'https://media.rawg.io/media/games/f61/f618468eb87b1c62301f566b457f94b5.jpg'},
#    {'id': 1864,
#     'name': 'spells',
#     'slug': 'spells',
#     'language': 'eng',
#     'games_count': 385,
#     'image_background': 'https://media.rawg.io/media/screenshots/873/873f2dd4de2b303eef72fe66db325b12.jpg'},
#    {'id': 6706,
#     'name': 'connect',
#     'slug': 'connect',
#     'language': 'eng',
#     'games_count': 466,
#     'image_background': 'https://media.rawg.io/media/screenshots/2ea/2ea81924c6403174da63eb613786b10c.jpg'}],
#   'esrb_rating': {'id': 3,
#    'name': 'Teen',
#    'slug': 'teen',
#    'name_en': 'Teen',
#    'name_ru': 'С 13 лет'},
#   'user_game': None,
#   'reviews_count': 49,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/games/a0d/a0d24e2e37d0710a63df12df089e71f6.jpg'},
#    {'id': 2836847,
#     'image': 'https://media.rawg.io/media/screenshots/319/31974d1831711ce3e59e35c2c72cec35.jpg'},
#    {'id': 2836848,
#     'image': 'https://media.rawg.io/media/screenshots/481/481d40e3747605fb6579b637f5160826.jpg'},
#    {'id': 2836849,
#     'image': 'https://media.rawg.io/media/screenshots/e88/e8801141e9818d11285e1a75d4b4b0ea.jpg'},
#    {'id': 2836850,
#     'image': 'https://media.rawg.io/media/screenshots/188/1889df3d79781c171bc9e6649e6764de.jpg'},
#    {'id': 2836851,
#     'image': 'https://media.rawg.io/media/screenshots/c22/c22fc69a4dfa5b591d267cff9a74a01f.jpg'},
#    {'id': 2836852,
#     'image': 'https://media.rawg.io/media/screenshots/e7e/e7e810281dfc12c520282c434dee0de9.jpg'}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#    {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}},
#    {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}},
#    {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}},
#    {'platform': {'id': 7, 'name': 'Nintendo', 'slug': 'nintendo'}}],
#   'genres': [{'id': 4, 'name': 'Action', 'slug': 'action'},
#    {'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#  {'slug': 'baldurs-gate-enhanced-edition',
#   'name': "Baldur's Gate: Enhanced Edition",
#   'playtime': 4,
#   'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one'}},
#    {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4'}},
#    {'platform': {'id': 7,
#      'name': 'Nintendo Switch',
#      'slug': 'nintendo-switch'}},
#    {'platform': {'id': 3, 'name': 'iOS', 'slug': 'ios'}},
#    {'platform': {'id': 21, 'name': 'Android', 'slug': 'android'}},
#    {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}},
#    {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}}],
#   'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}},
#    {'store': {'id': 4, 'name': 'App Store', 'slug': 'apple-appstore'}},
#    {'store': {'id': 5, 'name': 'GOG', 'slug': 'gog'}},
#    {'store': {'id': 8, 'name': 'Google Play', 'slug': 'google-play'}}],
#   'released': '2012-11-28',
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/games/313/3136687fb0b34490d082b7272a0868e2.jpg',
#   'rating': 4.11,
#   'rating_top': 4,
#   'ratings': [{'id': 4,
#     'title': 'recommended',
#     'count': 153,
#     'percent': 49.51},
#    {'id': 5, 'title': 'exceptional', 'count': 112, 'percent': 36.25},
#    {'id': 3, 'title': 'meh', 'count': 27, 'percent': 8.74},
#    {'id': 1, 'title': 'skip', 'count': 17, 'percent': 5.5}],
#   'ratings_count': 302,
#   'reviews_text_count': 4,
#   'added': 2736,
#   'added_by_status': {'yet': 221,
#    'owned': 2113,
#    'beaten': 188,
#    'toplay': 78,
#    'dropped': 99,
#    'playing': 37},
#   'metacritic': 78,
#   'suggestions_count': 521,
#   'updated': '2024-04-17T14:55:44',
#   'id': 464,
#   'score': '30.860523',
#   'clip': None,
#   'tags': [{'id': 31,
#     'name': 'Singleplayer',
#     'slug': 'singleplayer',
#     'language': 'eng',
#     'games_count': 220522,
#     'image_background': 'https://media.rawg.io/media/games/511/5118aff5091cb3efec399c808f8c598f.jpg'},
#    {'id': 42396,
#     'name': 'Для одного игрока',
#     'slug': 'dlia-odnogo-igroka',
#     'language': 'rus',
#     'games_count': 46028,
#     'image_background': 'https://media.rawg.io/media/games/8cc/8cce7c0e99dcc43d66c8efd42f9d03e3.jpg'},
#    {'id': 42392,
#     'name': 'Приключение',
#     'slug': 'prikliuchenie',
#     'language': 'rus',
#     'games_count': 36505,
#     'image_background': 'https://media.rawg.io/media/games/2ba/2bac0e87cf45e5b508f227d281c9252a.jpg'},
#    {'id': 40847,
#     'name': 'Steam Achievements',
#     'slug': 'steam-achievements',
#     'language': 'eng',
#     'games_count': 36657,
#     'image_background': 'https://media.rawg.io/media/games/490/49016e06ae2103881ff6373248843069.jpg'},
#    {'id': 7,
#     'name': 'Multiplayer',
#     'slug': 'multiplayer',
#     'language': 'eng',
#     'games_count': 37503,
#     'image_background': 'https://media.rawg.io/media/games/b49/b4912b5dbfc7ed8927b65f05b8507f6c.jpg'},
#    {'id': 13,
#     'name': 'Atmospheric',
#     'slug': 'atmospheric',
#     'language': 'eng',
#     'games_count': 32548,
#     'image_background': 'https://media.rawg.io/media/games/f46/f466571d536f2e3ea9e815ad17177501.jpg'},
#    {'id': 42425,
#     'name': 'Для нескольких игроков',
#     'slug': 'dlia-neskolkikh-igrokov',
#     'language': 'rus',
#     'games_count': 9491,
#     'image_background': 'https://media.rawg.io/media/games/4a0/4a0a1316102366260e6f38fd2a9cfdce.jpg'},
#    {'id': 42400,
#     'name': 'Атмосфера',
#     'slug': 'atmosfera',
#     'language': 'rus',
#     'games_count': 6083,
#     'image_background': 'https://media.rawg.io/media/games/960/960b601d9541cec776c5fa42a00bf6c4.jpg'},
#    {'id': 7808,
#     'name': 'steam-trading-cards',
#     'slug': 'steam-trading-cards',
#     'language': 'eng',
#     'games_count': 7569,
#     'image_background': 'https://media.rawg.io/media/games/310/3106b0e012271c5ffb16497b070be739.jpg'},
#    {'id': 42394,
#     'name': 'Глубокий сюжет',
#     'slug': 'glubokii-siuzhet',
#     'language': 'rus',
#     'games_count': 11861,
#     'image_background': 'https://media.rawg.io/media/games/4be/4be6a6ad0364751a96229c56bf69be59.jpg'},
#    {'id': 24,
#     'name': 'RPG',
#     'slug': 'rpg',
#     'language': 'eng',
#     'games_count': 20341,
#     'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'},
#    {'id': 18,
#     'name': 'Co-op',
#     'slug': 'co-op',
#     'language': 'eng',
#     'games_count': 11289,
#     'image_background': 'https://media.rawg.io/media/games/d0f/d0f91fe1d92332147e5db74e207cfc7a.jpg'},
#    {'id': 42412,
#     'name': 'Ролевая игра',
#     'slug': 'rolevaia-igra',
#     'language': 'rus',
#     'games_count': 16754,
#     'image_background': 'https://media.rawg.io/media/games/4e0/4e0e7b6d6906a131307c94266e5c9a1c.jpg'},
#    {'id': 118,
#     'name': 'Story Rich',
#     'slug': 'story-rich',
#     'language': 'eng',
#     'games_count': 21003,
#     'image_background': 'https://media.rawg.io/media/games/8a0/8a02f84a5916ede2f923b88d5f8217ba.jpg'},
#    {'id': 411,
#     'name': 'cooperative',
#     'slug': 'cooperative',
#     'language': 'eng',
#     'games_count': 4818,
#     'image_background': 'https://media.rawg.io/media/games/dd5/dd50d4266915d56dd5b63ae1bf72606a.jpg'},
#    {'id': 42421,
#     'name': 'Стратегия',
#     'slug': 'strategiia',
#     'language': 'rus',
#     'games_count': 18185,
#     'image_background': 'https://media.rawg.io/media/games/858/858c016de0cf7bc21a57dcc698a04a0c.jpg'},
#    {'id': 42435,
#     'name': 'Шедевр',
#     'slug': 'shedevr',
#     'language': 'rus',
#     'games_count': 1059,
#     'image_background': 'https://media.rawg.io/media/games/b49/b4912b5dbfc7ed8927b65f05b8507f6c.jpg'},
#    {'id': 9,
#     'name': 'Online Co-Op',
#     'slug': 'online-co-op',
#     'language': 'eng',
#     'games_count': 5356,
#     'image_background': 'https://media.rawg.io/media/games/15c/15c95a4915f88a3e89c821526afe05fc.jpg'},
#    {'id': 42480,
#     'name': 'Фэнтези',
#     'slug': 'fentezi',
#     'language': 'rus',
#     'games_count': 10958,
#     'image_background': 'https://media.rawg.io/media/games/d0f/d0f91fe1d92332147e5db74e207cfc7a.jpg'},
#    {'id': 64,
#     'name': 'Fantasy',
#     'slug': 'fantasy',
#     'language': 'eng',
#     'games_count': 27201,
#     'image_background': 'https://media.rawg.io/media/games/d2c/d2c74dacd89fd817c2deb625b01adb1a.jpg'},
#    {'id': 42461,
#     'name': 'Классика',
#     'slug': 'klassika',
#     'language': 'rus',
#     'games_count': 1452,
#     'image_background': 'https://media.rawg.io/media/games/7a2/7a2500ee8b2c0e1ff268bb4479463dea.jpg'},
#    {'id': 193,
#     'name': 'Classic',
#     'slug': 'classic',
#     'language': 'eng',
#     'games_count': 1788,
#     'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'},
#    {'id': 189,
#     'name': 'Female Protagonist',
#     'slug': 'female-protagonist',
#     'language': 'eng',
#     'games_count': 12087,
#     'image_background': 'https://media.rawg.io/media/games/63f/63f0e68688cad279ed38cde931dbfcdb.jpg'},
#    {'id': 42433,
#     'name': 'Совместная игра по сети',
#     'slug': 'sovmestnaia-igra-po-seti',
#     'language': 'rus',
#     'games_count': 1226,
#     'image_background': 'https://media.rawg.io/media/games/d69/d69810315bd7e226ea2d21f9156af629.jpg'},
#    {'id': 40832,
#     'name': 'Cross-Platform Multiplayer',
#     'slug': 'cross-platform-multiplayer',
#     'language': 'eng',
#     'games_count': 2552,
#     'image_background': 'https://media.rawg.io/media/games/9f1/9f1891779cb20f44de93cef33b067e50.jpg'},
#    {'id': 42530,
#     'name': 'Кастомизация персонажа',
#     'slug': 'kastomizatsiia-personazha',
#     'language': 'rus',
#     'games_count': 3674,
#     'image_background': 'https://media.rawg.io/media/games/c22/c22d804ac753c72f2617b3708a625dec.jpg'},
#    {'id': 121,
#     'name': 'Character Customization',
#     'slug': 'character-customization',
#     'language': 'eng',
#     'games_count': 4450,
#     'image_background': 'https://media.rawg.io/media/games/6fc/6fcf4cd3b17c288821388e6085bb0fc9.jpg'},
#    {'id': 40833,
#     'name': 'Captions available',
#     'slug': 'captions-available',
#     'language': 'eng',
#     'games_count': 1322,
#     'image_background': 'https://media.rawg.io/media/games/46d/46d98e6910fbc0706e2948a7cc9b10c5.jpg'},
#    {'id': 42576,
#     'name': 'Изометрия',
#     'slug': 'izometriia',
#     'language': 'rus',
#     'games_count': 1899,
#     'image_background': 'https://media.rawg.io/media/games/d4b/d4bcd78873edd9992d93aff9cc8db0c8.jpg'},
#    {'id': 99,
#     'name': 'Isometric',
#     'slug': 'isometric',
#     'language': 'eng',
#     'games_count': 4364,
#     'image_background': 'https://media.rawg.io/media/games/a92/a92272ea5cfc35b8ad6317fbd81ce0f6.jpg'},
#    {'id': 82,
#     'name': 'Magic',
#     'slug': 'magic',
#     'language': 'eng',
#     'games_count': 9210,
#     'image_background': 'https://media.rawg.io/media/games/ccf/ccf26f6e3d553a04f0033a8107a521b8.jpg'},
#    {'id': 42478,
#     'name': 'Магия',
#     'slug': 'magiia',
#     'language': 'rus',
#     'games_count': 3847,
#     'image_background': 'https://media.rawg.io/media/games/f6b/f6bed028b02369d4cab548f4f9337e81.jpg'},
#    {'id': 42466,
#     'name': 'Римейк',
#     'slug': 'rimeik',
#     'language': 'rus',
#     'games_count': 206,
#     'image_background': 'https://media.rawg.io/media/games/444/4440f674e2bcb257e249a9ab595d8ab6.jpg'},
#    {'id': 271,
#     'name': 'Remake',
#     'slug': 'remake',
#     'language': 'eng',
#     'games_count': 1697,
#     'image_background': 'https://media.rawg.io/media/games/444/4440f674e2bcb257e249a9ab595d8ab6.jpg'},
#    {'id': 42552,
#     'name': 'Можно приостановить',
#     'slug': 'mozhno-priostanovit',
#     'language': 'rus',
#     'games_count': 284,
#     'image_background': 'https://media.rawg.io/media/games/dc0/dc0926d3f84ffbcc00968fe8a6f0aed3.jpg'},
#    {'id': 194,
#     'name': 'Real-Time with Pause',
#     'slug': 'real-time-with-pause',
#     'language': 'eng',
#     'games_count': 215,
#     'image_background': 'https://media.rawg.io/media/screenshots/37b/37b929f27906b62a0bdbb733b2cd0ce6.jpeg'},
#    {'id': 60,
#     'name': 'Touch-Friendly',
#     'slug': 'touch-friendly',
#     'language': 'eng',
#     'games_count': 1665,
#     'image_background': 'https://media.rawg.io/media/games/d28/d28e64fd1af23d1846d20b47dfa933f8.jpeg'},
#    {'id': 42626,
#     'name': 'Компьютерная ролевая игра',
#     'slug': 'kompiuternaia-rolevaia-igra',
#     'language': 'rus',
#     'games_count': 1005,
#     'image_background': 'https://media.rawg.io/media/games/963/9639183ff27251b0b686acaa6aac0297.jpg'},
#    {'id': 238,
#     'name': 'CRPG',
#     'slug': 'crpg',
#     'language': 'eng',
#     'games_count': 999,
#     'image_background': 'https://media.rawg.io/media/games/699/69907ecf13f172e9e144069769c3be73.jpg'},
#    {'id': 42625,
#     'name': 'Партийная ролевая игра',
#     'slug': 'partiinaia-rolevaia-igra',
#     'language': 'rus',
#     'games_count': 1058,
#     'image_background': 'https://media.rawg.io/media/screenshots/d39/d39aeca90fad83dd776730e7c13271d6.jpg'},
#    {'id': 206,
#     'name': 'Party-Based RPG',
#     'slug': 'party-based-rpg',
#     'language': 'eng',
#     'games_count': 1005,
#     'image_background': 'https://media.rawg.io/media/games/add/add07a75a3f1e479b55dbe920d9fb13d.jpg'},
#    {'id': 574,
#     'name': 'Dungeons & Dragons',
#     'slug': 'dungeons-dragons',
#     'language': 'eng',
#     'games_count': 185,
#     'image_background': 'https://media.rawg.io/media/games/246/246367eab7ccfaaad14ad4507deee067.jpeg'}],
#   'esrb_rating': {'id': 3,
#    'name': 'Teen',
#    'slug': 'teen',
#    'name_en': 'Teen',
#    'name_ru': 'С 13 лет'},
#   'user_game': None,
#   'reviews_count': 309,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/games/313/3136687fb0b34490d082b7272a0868e2.jpg'},
#    {'id': 165291,
#     'image': 'https://media.rawg.io/media/screenshots/0ae/0aef02ef658846e4b61401031c9eff18.jpg'},
#    {'id': 165292,
#     'image': 'https://media.rawg.io/media/screenshots/466/466fa28cbaeaf24ee25965672c9880dc.jpg'},
#    {'id': 165293,
#     'image': 'https://media.rawg.io/media/screenshots/469/469012e0550883ffbb701d5bd1a8cf81.jpg'},
#    {'id': 165294,
#     'image': 'https://media.rawg.io/media/screenshots/5f1/5f10dd4dc5d870dab674d25c7e9a9433.jpg'},
#    {'id': 165295,
#     'image': 'https://media.rawg.io/media/screenshots/94e/94e436eea04afec1be5fd57fc38f424e.jpg'},
#    {'id': 165296,
#     'image': 'https://media.rawg.io/media/screenshots/64e/64e58b1c8e93e3be699a25da3bfdf062.jpg'}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#    {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}},
#    {'platform': {'id': 4, 'name': 'iOS', 'slug': 'ios'}},
#    {'platform': {'id': 8, 'name': 'Android', 'slug': 'android'}},
#    {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}},
#    {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}},
#    {'platform': {'id': 7, 'name': 'Nintendo', 'slug': 'nintendo'}}],
#   'genres': [{'id': 10, 'name': 'Strategy', 'slug': 'strategy'},
#    {'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#  {'slug': 'baldurs-gate-ii-ee',
#   'name': "Baldur's Gate II: Enhanced Edition",
#   'playtime': 4,
#   'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one'}},
#    {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4'}},
#    {'platform': {'id': 7,
#      'name': 'Nintendo Switch',
#      'slug': 'nintendo-switch'}},
#    {'platform': {'id': 3, 'name': 'iOS', 'slug': 'ios'}},
#    {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}},
#    {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}}],
#   'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}},
#    {'store': {'id': 4, 'name': 'App Store', 'slug': 'apple-appstore'}},
#    {'store': {'id': 5, 'name': 'GOG', 'slug': 'gog'}}],
#   'released': '2013-11-15',
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/screenshots/e0a/e0abaefbcc99ef995be57d857806f2d2.jpeg',
#   'rating': 4.25,
#   'rating_top': 5,
#   'ratings': [{'id': 5,
#     'title': 'exceptional',
#     'count': 126,
#     'percent': 55.26},
#    {'id': 4, 'title': 'recommended', 'count': 71, 'percent': 31.14},
#    {'id': 1, 'title': 'skip', 'count': 19, 'percent': 8.33},
#    {'id': 3, 'title': 'meh', 'count': 12, 'percent': 5.26}],
#   'ratings_count': 224,
#   'reviews_text_count': 2,
#   'added': 2392,
#   'added_by_status': {'yet': 252,
#    'owned': 1848,
#    'beaten': 115,
#    'toplay': 91,
#    'dropped': 66,
#    'playing': 20},
#   'metacritic': 78,
#   'suggestions_count': 835,
#   'updated': '2024-01-24T08:44:34',
#   'id': 16003,
#   'score': '29.72705',
#   'clip': None,
#   'tags': [{'id': 31,
#     'name': 'Singleplayer',
#     'slug': 'singleplayer',
#     'language': 'eng',
#     'games_count': 220522,
#     'image_background': 'https://media.rawg.io/media/games/511/5118aff5091cb3efec399c808f8c598f.jpg'},
#    {'id': 42396,
#     'name': 'Для одного игрока',
#     'slug': 'dlia-odnogo-igroka',
#     'language': 'rus',
#     'games_count': 46028,
#     'image_background': 'https://media.rawg.io/media/games/8cc/8cce7c0e99dcc43d66c8efd42f9d03e3.jpg'},
#    {'id': 42392,
#     'name': 'Приключение',
#     'slug': 'prikliuchenie',
#     'language': 'rus',
#     'games_count': 36505,
#     'image_background': 'https://media.rawg.io/media/games/2ba/2bac0e87cf45e5b508f227d281c9252a.jpg'},
#    {'id': 40847,
#     'name': 'Steam Achievements',
#     'slug': 'steam-achievements',
#     'language': 'eng',
#     'games_count': 36657,
#     'image_background': 'https://media.rawg.io/media/games/490/49016e06ae2103881ff6373248843069.jpg'},
#    {'id': 7,
#     'name': 'Multiplayer',
#     'slug': 'multiplayer',
#     'language': 'eng',
#     'games_count': 37503,
#     'image_background': 'https://media.rawg.io/media/games/b49/b4912b5dbfc7ed8927b65f05b8507f6c.jpg'},
#    {'id': 13,
#     'name': 'Atmospheric',
#     'slug': 'atmospheric',
#     'language': 'eng',
#     'games_count': 32548,
#     'image_background': 'https://media.rawg.io/media/games/f46/f466571d536f2e3ea9e815ad17177501.jpg'},
#    {'id': 42425,
#     'name': 'Для нескольких игроков',
#     'slug': 'dlia-neskolkikh-igrokov',
#     'language': 'rus',
#     'games_count': 9491,
#     'image_background': 'https://media.rawg.io/media/games/4a0/4a0a1316102366260e6f38fd2a9cfdce.jpg'},
#    {'id': 42400,
#     'name': 'Атмосфера',
#     'slug': 'atmosfera',
#     'language': 'rus',
#     'games_count': 6083,
#     'image_background': 'https://media.rawg.io/media/games/960/960b601d9541cec776c5fa42a00bf6c4.jpg'},
#    {'id': 7808,
#     'name': 'steam-trading-cards',
#     'slug': 'steam-trading-cards',
#     'language': 'eng',
#     'games_count': 7569,
# ...
#     'image_background': 'https://media.rawg.io/media/games/f6b/f6bed028b02369d4cab548f4f9337e81.jpg'},
#    {'id': 42512,
#     'name': 'Олдскул',
#     'slug': 'oldskul',
#     'language': 'rus',
#     'games_count': 3600,
#     'image_background': 'https://media.rawg.io/media/games/c80/c80bcf321da44d69b18a06c04d942662.jpg'},
#    {'id': 48,
#     'name': 'Dungeon Crawler',
#     'slug': 'dungeon-crawler',
#     'language': 'eng',
#     'games_count': 6698,
#     'image_background': 'https://media.rawg.io/media/games/cef/cefedf18016cbab466861eb698daf988.jpg'},
#    {'id': 171,
#     'name': 'PvE',
#     'slug': 'pve',
#     'language': 'eng',
#     'games_count': 4589,
#     'image_background': 'https://media.rawg.io/media/screenshots/8a7/8a7586c647e10e6b6959df16d8bdc909.jpg'},
#    {'id': 42567,
#     'name': 'Игра против ИИ',
#     'slug': 'igra-protiv-ii',
#     'language': 'rus',
#     'games_count': 2327,
#     'image_background': 'https://media.rawg.io/media/games/f87/f87457e8347484033cb34cde6101d08d.jpg'},
#    {'id': 58127,
#     'name': 'Бой',
#     'slug': 'boi-2',
#     'language': 'rus',
#     'games_count': 6548,
#     'image_background': 'https://media.rawg.io/media/games/e85/e851f527ab0658519436342ee73da191.jpg'},
#    {'id': 42626,
#     'name': 'Компьютерная ролевая игра',
#     'slug': 'kompiuternaia-rolevaia-igra',
#     'language': 'rus',
#     'games_count': 1005,
#     'image_background': 'https://media.rawg.io/media/games/963/9639183ff27251b0b686acaa6aac0297.jpg'},
#    {'id': 238,
#     'name': 'CRPG',
#     'slug': 'crpg',
#     'language': 'eng',
#     'games_count': 999,
#     'image_background': 'https://media.rawg.io/media/games/699/69907ecf13f172e9e144069769c3be73.jpg'},
#    {'id': 45201,
#     'name': 'Remote Play Together',
#     'slug': 'remote-play-together',
#     'language': 'eng',
#     'games_count': 2685,
#     'image_background': 'https://media.rawg.io/media/screenshots/cc0/cc064ab715ba4195ac6d26250218e307.jpg'},
#    {'id': 46112,
#     'name': 'Shared/Split Screen Co-op',
#     'slug': 'sharedsplit-screen-co-op',
#     'language': 'eng',
#     'games_count': 1734,
#     'image_background': 'https://media.rawg.io/media/games/3f4/3f43f03406a5ea087352bf32d60e3a0a.jpg'},
#    {'id': 570,
#     'name': 'Old School',
#     'slug': 'old-school',
#     'language': 'eng',
#     'games_count': 3351,
#     'image_background': 'https://media.rawg.io/media/screenshots/1d6/1d66c38dedaf68ff0bd73087128016a3.jpg'},
#    {'id': 2889,
#     'name': 'balance',
#     'slug': 'balance',
#     'language': 'eng',
#     'games_count': 1675,
#     'image_background': 'https://media.rawg.io/media/games/19e/19ea8efb10fcbcf1b9c60729d510ed14.jpg'},
#    {'id': 58131,
#     'name': 'Подземелья',
#     'slug': 'podzemelia',
#     'language': 'rus',
#     'games_count': 1750,
#     'image_background': 'https://media.rawg.io/media/screenshots/029/029473dcb7952e3eb154fbae4078437f.jpg'},
#    {'id': 70354,
#     'name': 'Локальный кооператив',
#     'slug': 'lokalnyi-kooperativ',
#     'language': 'rus',
#     'games_count': 866,
#     'image_background': 'https://media.rawg.io/media/screenshots/166/166e17d403f74bd4494ae4dcb289ad2c.jpg'}],
#   'esrb_rating': None,
#   'user_game': None,
#   'reviews_count': 19,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/46a/46a479d0645f4a95b289affe66603d00.jpg'},
#    {'id': 803022,
#     'image': 'https://media.rawg.io/media/screenshots/b09/b09e4b23e67c4ae116e07e79b23a0e55.jpg'},
#    {'id': 803023,
#     'image': 'https://media.rawg.io/media/screenshots/152/152392c96c8f8930581ef31bb5f2181d.jpg'},
#    {'id': 803024,
#     'image': 'https://media.rawg.io/media/screenshots/41a/41aaacd43478107446fe256e1906205e.jpg'},
#    {'id': 803025,
#     'image': 'https://media.rawg.io/media/screenshots/33d/33d62c242586ad446fe1f8f78c6153bb.jpg'},
#    {'id': 803026,
#     'image': 'https://media.rawg.io/media/screenshots/46a/46a479d0645f4a95b289affe66603d00.jpg'}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#    {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}},
#    {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}},
#    {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}}],
#   'genres': [{'id': 4, 'name': 'Action', 'slug': 'action'},
#    {'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#  {'slug': 'baldurs-gate-ii-throne-of-bhaal',
#   'name': "Baldur's Gate II: Throne of Bhaal",
#   'playtime': 3,
#   'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#   'stores': None,
#   'released': '2001-06-22',
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/games/02b/02b277e0fe92bb4b609b296b7cc12e88.jpg',
#   'rating': 4.34,
#   'rating_top': 5,
#   'ratings': [{'id': 5, 'title': 'exceptional', 'count': 45, 'percent': 64.29},
#    {'id': 4, 'title': 'recommended', 'count': 16, 'percent': 22.86},
#    {'id': 1, 'title': 'skip', 'count': 6, 'percent': 8.57},
#    {'id': 3, 'title': 'meh', 'count': 3, 'percent': 4.29}],
#   'ratings_count': 70,
#   'reviews_text_count': 0,
#   'added': 164,
#   'added_by_status': {'yet': 18,
#    'owned': 33,
#    'beaten': 61,
#    'toplay': 31,
#    'dropped': 17,
#    'playing': 4},
#   'metacritic': None,
#   'suggestions_count': 578,
#   'updated': '2023-12-16T17:49:37',
#   'id': 29727,
#   'score': '26.796427',
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'user_game': None,
#   'reviews_count': 70,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/games/02b/02b277e0fe92bb4b609b296b7cc12e88.jpg'},
#    {'id': 293373,
#     'image': 'https://media.rawg.io/media/screenshots/181/1816b4a4366c327d199d45cd6ff0ae4e.jpg'},
#    {'id': 293374,
#     'image': 'https://media.rawg.io/media/screenshots/d33/d33c41d85e57577853c86c3d8c3189a3.jpg'},
#    {'id': 293375,
#     'image': 'https://media.rawg.io/media/screenshots/1d2/1d2f581d2bb64bc4efea63da3c429998.jpg'},
#    {'id': 293376,
#     'image': 'https://media.rawg.io/media/screenshots/f90/f9083d469ca17f04aa344ffba616214c.jpg'},
#    {'id': 293377,
#     'image': 'https://media.rawg.io/media/screenshots/34e/34e65368aa4df3310b01d4cc59d28fe3.jpg'},
#    {'id': 293378,
#     'image': 'https://media.rawg.io/media/screenshots/682/682b50a8ac0a8f414b26e1dc4a2dc026.jpg'}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#   'genres': [{'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#  {'slug': 'baldurs-gate-tales-of-the-sword-coast',
#   'name': "Baldur's Gate: Tales of the Sword Coast",
#   'playtime': 0,
#   'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#   'stores': None,
#   'released': '1999-04-30',
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/screenshots/9b9/9b988c28c21c4f7132fdfc6eb43a4bcc.jpg',
#   'rating': 4.15,
#   'rating_top': 4,
#   'ratings': [{'id': 4, 'title': 'recommended', 'count': 17, 'percent': 50.0},
#    {'id': 5, 'title': 'exceptional', 'count': 12, 'percent': 35.29},
#    {'id': 3, 'title': 'meh', 'count': 4, 'percent': 11.76},
#    {'id': 1, 'title': 'skip', 'count': 1, 'percent': 2.94}],
#   'ratings_count': 34,
#   'reviews_text_count': 0,
#   'added': 81,
#   'added_by_status': {'yet': 11,
#    'owned': 16,
#    'beaten': 34,
#    'toplay': 15,
#    'dropped': 5},
#   'metacritic': None,
#   'suggestions_count': 517,
#   'updated': '2023-07-25T17:26:22',
#   'id': 31153,
#   'score': '25.701893',
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'user_game': None,
#   'reviews_count': 34,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/9b9/9b988c28c21c4f7132fdfc6eb43a4bcc.jpg'},
#    {'id': 313002,
#     'image': 'https://media.rawg.io/media/screenshots/259/259810c3189c56d32f41ed00faf77db8.jpg'},
#    {'id': 313003,
#     'image': 'https://media.rawg.io/media/screenshots/1e4/1e4f09e19ff03f02d73dfd99e341182e.jpg'},
#    {'id': 313004,
#     'image': 'https://media.rawg.io/media/screenshots/9f3/9f3ce84e07314462aebfa58f1147abaf.jpg'},
#    {'id': 313005,
#     'image': 'https://media.rawg.io/media/screenshots/dd9/dd9e955019c19913e1318522f55b11ab.jpg'},
#    {'id': 313006,
#     'image': 'https://media.rawg.io/media/screenshots/ea6/ea6b1b6bcef8dc17b431b82c4595e8bf.jpg'},
#    {'id': 313007,
#     'image': 'https://media.rawg.io/media/screenshots/b79/b79790cfcf414f3f69c98a3ef20879bb.jpg'}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#   'genres': [{'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#  {'slug': 'baldurs-gate-ii-shadows-of-amn',
#   'name': "Baldur's Gate II: Shadows of Amn",
#   'playtime': 1,
#   'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 21, 'name': 'Android', 'slug': 'android'}},
#    {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}}],
#   'stores': [{'store': {'id': 4,
#      'name': 'App Store',
#      'slug': 'apple-appstore'}},
#    {'store': {'id': 8, 'name': 'Google Play', 'slug': 'google-play'}}],
#   'released': '2000-09-21',
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/games/c16/c160077f8977cb22f14e56408c1560ef.jpg',
#   'rating': 4.34,
#   'rating_top': 5,
#   'ratings': [{'id': 5,
#     'title': 'exceptional',
#     'count': 101,
#     'percent': 69.18},
#    {'id': 4, 'title': 'recommended', 'count': 22, 'percent': 15.07},
#    {'id': 1, 'title': 'skip', 'count': 14, 'percent': 9.59},
#    {'id': 3, 'title': 'meh', 'count': 9, 'percent': 6.16}],
#   'ratings_count': 143,
#   'reviews_text_count': 2,
#   'added': 341,
#   'added_by_status': {'yet': 47,
#    'owned': 82,
#    'beaten': 113,
#    'toplay': 58,
#    'dropped': 35,
#    'playing': 6},
#   'metacritic': 95,
#   'suggestions_count': 530,
#   'updated': '2023-12-08T05:51:51',
#   'id': 30799,
#   'score': '22.958698',
#   'clip': None,
#   'tags': [{'id': 41,
#     'name': 'Dark',
#     'slug': 'dark',
#     'language': 'eng',
#     'games_count': 15406,
#     'image_background': 'https://media.rawg.io/media/games/4fb/4fb548e4816c84d1d70f1a228fb167cc.jpg'},
#    {'id': 82,
#     'name': 'Magic',
#     'slug': 'magic',
#     'language': 'eng',
#     'games_count': 9210,
#     'image_background': 'https://media.rawg.io/media/games/ccf/ccf26f6e3d553a04f0033a8107a521b8.jpg'},
#    {'id': 270,
#     'name': 'Blood',
#     'slug': 'blood',
#     'language': 'eng',
#     'games_count': 2045,
#     'image_background': 'https://media.rawg.io/media/screenshots/f2f/f2f3c93d6153da7aee590f3ab8ccd803.jpg'},
#    {'id': 981,
#     'name': 'battle',
#     'slug': 'battle',
#     'language': 'eng',
#     'games_count': 10618,
#     'image_background': 'https://media.rawg.io/media/screenshots/db5/db5ab0d41a2a57274902d32ea8e6f1ec.jpg'},
#    {'id': 51,
#     'name': 'Destruction',
#     'slug': 'destruction',
#     'language': 'eng',
#     'games_count': 3558,
#     'image_background': 'https://media.rawg.io/media/games/9da/9da42a4da370cc386c8578f0b2578e2c.jpg'},
#    {'id': 215,
#     'name': 'Dragons',
#     'slug': 'dragons',
#     'language': 'eng',
#     'games_count': 2565,
#     'image_background': 'https://media.rawg.io/media/games/62c/62c7c8b28a27b83680b22fb9d33fc619.jpg'},
#    {'id': 774,
#     'name': 'nature',
#     'slug': 'nature',
#     'language': 'eng',
#     'games_count': 5658,
#     'image_background': 'https://media.rawg.io/media/screenshots/370/370dbc27b2ff669c508c029d39b825be.jpg'},
#    {'id': 3046,
#     'name': 'destroy',
#     'slug': 'destroy',
#     'language': 'eng',
#     'games_count': 4608,
#     'image_background': 'https://media.rawg.io/media/games/922/92244532ff3c3f277824c0cf8941f187.jpg'},
#    {'id': 704,
#     'name': 'Traps',
#     'slug': 'traps',
#     'language': 'eng',
#     'games_count': 2191,
#     'image_background': 'https://media.rawg.io/media/screenshots/7cd/7cdfb1ec2f8d618ec951ddf17deff6b2.jpg'},
#    {'id': 574,
#     'name': 'Dungeons & Dragons',
#     'slug': 'dungeons-dragons',
#     'language': 'eng',
#     'games_count': 185,
#     'image_background': 'https://media.rawg.io/media/games/246/246367eab7ccfaaad14ad4507deee067.jpeg'},
#    {'id': 3680,
#     'name': 'defense',
#     'slug': 'defense',
#     'language': 'eng',
#     'games_count': 2472,
#     'image_background': 'https://media.rawg.io/media/screenshots/8c9/8c98852ee8f7a9891bb97ddf707be8d4.jpg'},
#    {'id': 920,
#     'name': 'murder',
#     'slug': 'murder',
#     'language': 'eng',
#     'games_count': 741,
#     'image_background': 'https://media.rawg.io/media/games/c16/c160077f8977cb22f14e56408c1560ef.jpg'},
#    {'id': 3626,
#     'name': 'treasure',
#     'slug': 'treasure',
#     'language': 'eng',
#     'games_count': 1871,
#     'image_background': 'https://media.rawg.io/media/screenshots/e94/e94aac28a7b797d4647d448cab957dc5.jpg'},
#    {'id': 712,
#     'name': 'school',
#     'slug': 'school',
#     'language': 'eng',
#     'games_count': 4566,
#     'image_background': 'https://media.rawg.io/media/screenshots/2d9/2d9332487fe455e819d0fe2e9064a00a_HxNGzSI.jpg'},
#    {'id': 2489,
#     'name': 'dodge',
#     'slug': 'dodge',
#     'language': 'eng',
#     'games_count': 2974,
#     'image_background': 'https://media.rawg.io/media/screenshots/86a/86a1ca92bee366c36e30aad87c0604ee.jpg'},
#    {'id': 5506,
#     'name': 'wizards',
#     'slug': 'wizards',
#     'language': 'eng',
#     'games_count': 1050,
#     'image_background': 'https://media.rawg.io/media/games/6f5/6f5a86874e87f6f8d63caad6e4a3b49f.jpg'},
#    {'id': 6715,
#     'name': 'dnd',
#     'slug': 'dnd',
#     'language': 'eng',
#     'games_count': 173,
#     'image_background': 'https://media.rawg.io/media/screenshots/8f6/8f6a7bb60fe09cd598dc5b2d5305c9ce.jpg'},
#    {'id': 7642,
#     'name': 'dungeons-and-dragons',
#     'slug': 'dungeons-and-dragons',
#     'language': 'eng',
#     'games_count': 42,
#     'image_background': 'https://media.rawg.io/media/screenshots/31d/31df47a3b0da5c407130b83bdab9024e.jpg'},
#    {'id': 73064,
#     'name': 'ad&d',
#     'slug': 'add-2',
#     'language': 'eng',
#     'games_count': 1,
#     'image_background': 'https://media.rawg.io/media/games/c16/c160077f8977cb22f14e56408c1560ef.jpg'},
#    {'id': 73065,
#     'name': 'd&d',
#     'slug': 'dd-2',
#     'language': 'eng',
#     'games_count': 1,
#     'image_background': 'https://media.rawg.io/media/games/c16/c160077f8977cb22f14e56408c1560ef.jpg'},
#    {'id': 73066,
#     'name': 'forgotten realms',
#     'slug': 'forgotten-realms',
#     'language': 'eng',
#     'games_count': 1,
#     'image_background': 'https://media.rawg.io/media/games/c16/c160077f8977cb22f14e56408c1560ef.jpg'},
#    {'id': 73067,
#     'name': 'forgotten-realms',
#     'slug': 'forgotten-realms-2',
#     'language': 'eng',
#     'games_count': 1,
#     'image_background': 'https://media.rawg.io/media/games/c16/c160077f8977cb22f14e56408c1560ef.jpg'}],
#   'esrb_rating': {'id': 3,
#    'name': 'Teen',
#    'slug': 'teen',
#    'name_en': 'Teen',
#    'name_ru': 'С 13 лет'},
#   'user_game': None,
#   'reviews_count': 146,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/games/c16/c160077f8977cb22f14e56408c1560ef.jpg'},
#    {'id': 308289,
#     'image': 'https://media.rawg.io/media/screenshots/797/797d84248b0717b2e68d3fe2c7b83caf.jpg'},
#    {'id': 308290,
#     'image': 'https://media.rawg.io/media/screenshots/a86/a86f494fab75588c65e9b81d986786e7.jpg'},
#    {'id': 308291,
#     'image': 'https://media.rawg.io/media/screenshots/a22/a22e5334b242888fe2297d5b2c956545.jpg'},
#    {'id': 308292,
#     'image': 'https://media.rawg.io/media/screenshots/61b/61b9c6f40d3366d309214474559b2234.jpg'},
#    {'id': 308293,
#     'image': 'https://media.rawg.io/media/screenshots/52c/52c0a4441ec2cc9d59edc866589fac5c.jpg'},
#    {'id': 308294,
#     'image': 'https://media.rawg.io/media/screenshots/85d/85da91fe0d6d33be76fa1a8f24e4f915.jpg'}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 8, 'name': 'Android', 'slug': 'android'}},
#    {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}}],
#   'genres': [{'id': 10, 'name': 'Strategy', 'slug': 'strategy'},
#    {'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]}]
